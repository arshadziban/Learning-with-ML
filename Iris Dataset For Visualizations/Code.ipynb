# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# Load iris dataset
iris_data = load_iris()
iris = pd.DataFrame(data=iris_data.data, columns=iris_data.feature_names)
iris['species'] = iris_data.target_names[iris_data.target]

# %%
sns.pairplot(iris, hue="species", markers=["o", "s", "D"])
plt.suptitle("Pair Plot of Iris Dataset", y=1.02)
plt.show()
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.lmplot(x='petal length (cm)', y='petal width (cm)', hue='species', data=iris, height=6)
plt.title("Petal Length vs Petal Width by Species")
plt.show()
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.boxplot(x="species", y="sepal length (cm)", data=iris)
plt.title("Sepal Length Distribution by Species")
plt.show()

# %%
sns.violinplot(x="species", y="petal length (cm)", data=iris)
plt.title("Distribution of Petal Length by Species")
plt.show()

# %%
sns.swarmplot(x="species", y="sepal width (cm)", data=iris)
plt.title("Swarm Plot of Sepal Width by Species")
plt.show()

# %%
import numpy as np

# Calculate correlation matrix
corr_matrix = iris.iloc[:, :-1].corr() 

# Plot heatmap
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Matrix of Iris Dataset")
plt.show()

# %%
g = sns.FacetGrid(iris, col="species")
g.map(plt.hist, "sepal length (cm)", bins=10)
plt.suptitle("Distribution of Sepal Length by Species", y=1.05)
plt.show()
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
