# %%
import pandas as pd
#read Data
df = pd.read_excel('temperature_data.xlsx')

# %%
#showing data
df.head()
# Out:
#    Chips  Temperature_Celsius
# 0   44.0               26.944
# 1   46.4               25.833
# 2   43.6               25.556
# 3   35.0               23.056
# 4   35.0               21.389

# %%
from matplotlib import pyplot as plt

# %%
plt.scatter(df['Chips'] , df['Temperature_Celsius'])
plt.xlabel('Chips')
plt.ylabel('Temperature_Celsius')
plt.title('Full dataset in graph')
# Out:
# Text(0.5, 1.0, 'Full dataset in graph')

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
X = df[['Chips']]
X.head()
# Out:
#    Chips
# 0   44.0
# 1   46.4
# 2   43.6
# 3   35.0
# 4   35.0

# %%
Y = df[['Temperature_Celsius']]
Y.head()
# Out:
#    Temperature_Celsius
# 0               26.944
# 1               25.833
# 2               25.556
# 3               23.056
# 4               21.389

# %%
X.mean()
# Out:
# Chips    28.805182
# dtype: float64

# %%
Y.mean()
# Out:
# Temperature_Celsius    18.729824
# dtype: float64

# %%
plt.scatter(X.mean() , Y.mean(), color='red')

# %%
reg.fit(X,Y)
# Out:
# LinearRegression()

# %%
m = reg.coef_
m
# Out:
# array([[0.49543812]])

# %%
c = reg.intercept_
c
# Out:
# array([4.45863852])

# %%
reg.predict([[34]])
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[21.30353459]])

# %%
df
# Out:
#      Chips  Temperature_Celsius  Predicted
# 0   44.000              26.9440  26.257916
# 1   46.400              25.8330  27.446967
# 2   43.600              25.5560  26.059741
# 3   35.000              23.0560  21.798973
# 4   35.000              21.3890  21.798973
# 5   32.600              20.0000  20.609921
# 6   28.900              18.8890  18.776800
# 7   27.700              18.3330  18.182274
# 8   25.500              16.3890  17.092311
# 9   20.375              13.8890  14.553190
# 10  12.500              12.7780  10.651615
# 11  37.000              24.5830  22.789849
# 12  37.500              23.3330  23.037568
# 13  36.500              23.3330  22.542130
# 14  36.200              22.5000  22.393498
# 15  33.000              18.8890  20.808096
# 16  43.000              25.2780  25.762478
# 17  46.000              25.8330  27.248792
# 18  29.000              20.2780  18.826344
# 19  31.700              20.2780  20.164027
# 20  31.000              20.0000  19.817220
# ...

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
mse = mean_squared_error(df['Temperature_Celsius'], df['Predicted'])
mse
# Out:
# 0.7707856265446018

# %%
mae = mean_absolute_error(df['Temperature_Celsius'], df['Predicted'])
mae
# Out:
# 0.6737279893724711
